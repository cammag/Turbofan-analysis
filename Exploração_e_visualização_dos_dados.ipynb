# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # **Análise exploratória dos dados**

# %%
#Importando os dados
dir_path = ''
train_file = 'train_FD001.txt'
test_file = 'test_FD001.txt'

index_names = ['ID', 'Cycle']
setting_names = ['OpSet1', 'OpSet2', 'OpSet3']
sensor_names = ['SensorMeasure{}'.format(i+1) for i in range(0,21)]
col_names = index_names + setting_names + sensor_names

df_train = pd.read_csv((dir_path+train_file), sep='\s+', header=None, 
                 names=col_names)
df_test = pd.read_csv((dir_path+test_file), sep='\s+', header=None, 
                 names=col_names)

# %%
df_RUL = pd.read_csv('RUL_FD001.txt', sep=" ", header=None)
df_RUL.drop(df_RUL.columns[[1]], axis=1, inplace=True)

df_RUL.head()
# Out:
#      0
# 0  112
# 1   98
# 2   69
# 3   82
# 4   91

# %%
df_train.describe()
# Out:
#                  ID         Cycle  ...  SensorMeasure20  SensorMeasure21
# count  20631.000000  20631.000000  ...     20631.000000     20631.000000
# mean      51.506568    108.807862  ...        38.816271        23.289705
# std       29.227633     68.880990  ...         0.180746         0.108251
# min        1.000000      1.000000  ...        38.140000        22.894200
# 25%       26.000000     52.000000  ...        38.700000        23.221800
# 50%       52.000000    104.000000  ...        38.830000        23.297900
# 75%       77.000000    156.000000  ...        38.950000        23.366800
# max      100.000000    362.000000  ...        39.430000        23.618400
#
# [8 rows x 26 columns]

# %%
print(df_train.shape)
df_train.head()
# Out:
# (20631, 26)
#    ID  Cycle  OpSet1  ...  SensorMeasure19  SensorMeasure20  SensorMeasure21
# 0   1      1 -0.0007  ...            100.0            39.06          23.4190
# 1   1      2  0.0019  ...            100.0            39.00          23.4236
# 2   1      3 -0.0043  ...            100.0            38.95          23.3442
# 3   1      4  0.0007  ...            100.0            38.88          23.3739
# 4   1      5 -0.0019  ...            100.0            38.90          23.4044
#
# [5 rows x 26 columns]

# %%
print(df_test.shape)
df_test.head()
# Out:
# (13096, 26)
#    ID  Cycle  OpSet1  ...  SensorMeasure19  SensorMeasure20  SensorMeasure21
# 0   1      1  0.0023  ...            100.0            38.86          23.3735
# 1   1      2 -0.0027  ...            100.0            39.02          23.3916
# 2   1      3  0.0003  ...            100.0            39.08          23.4166
# 3   1      4  0.0042  ...            100.0            39.00          23.3737
# 4   1      5  0.0014  ...            100.0            38.99          23.4130
#
# [5 rows x 26 columns]

# %%
# Gerando o RUL no conjunto de treino
rul = pd.DataFrame(df_train.groupby('ID')['Cycle'].max()).reset_index()
rul.columns = ['ID', 'Max']
df_train = df_train.merge(rul, on=['ID'], how='left')
df_train['RUL'] = df_train['Max'] - df_train['Cycle']
df_train.drop('Max', axis=1, inplace=True)
df_train.head()
# Out:
#    ID  Cycle  OpSet1  ...  SensorMeasure20  SensorMeasure21  RUL
# 0   1      1 -0.0007  ...            39.06          23.4190  191
# 1   1      2  0.0019  ...            39.00          23.4236  190
# 2   1      3 -0.0043  ...            38.95          23.3442  189
# 3   1      4  0.0007  ...            38.88          23.3739  188
# 4   1      5 -0.0019  ...            38.90          23.4044  187
#
# [5 rows x 27 columns]

# %%
# Analisando a distribuição de decaimento de vida das turbinas
df_max_rul = df_train[['ID', 'RUL']].groupby('ID').first().reset_index()
df_max_rul['RUL'].hist(bins=15, figsize=(15,7))
plt.xlabel("RUL")
plt.ylabel("frequencia")
plt.show()

# %%
# gerando a classe que será a janela de falha a ser prevista das turbinas
D = 30
# label é a classe que indica que irá falhar dentro da janela de 20 dias
# 1 indica falha, 0 indica que está saudável
df_train['label'] = np.where(df_train['RUL'] <= D, 1, 0 )
df_train
# Out:
#         ID  Cycle  OpSet1  OpSet2  ...  SensorMeasure20  SensorMeasure21  RUL  label
# 0        1      1 -0.0007 -0.0004  ...            39.06          23.4190  191      0
# 1        1      2  0.0019 -0.0003  ...            39.00          23.4236  190      0
# 2        1      3 -0.0043  0.0003  ...            38.95          23.3442  189      0
# 3        1      4  0.0007  0.0000  ...            38.88          23.3739  188      0
# 4        1      5 -0.0019 -0.0002  ...            38.90          23.4044  187      0
# ...    ...    ...     ...     ...  ...              ...              ...  ...    ...
# 20626  100    196 -0.0004 -0.0003  ...            38.49          22.9735    4      1
# 20627  100    197 -0.0016 -0.0005  ...            38.30          23.1594    3      1
# 20628  100    198  0.0004  0.0000  ...            38.44          22.9333    2      1
# 20629  100    199 -0.0011  0.0003  ...            38.29          23.0640    1      1
# ...

# %%
# Colocando as labels em strings para o gráfico
df_train['label2'] = np.where(df_train['RUL'] <= D, "1", "0" )
df_train
# Out:
#         ID  Cycle  OpSet1  OpSet2  ...  SensorMeasure21  RUL  label  label2
# 0        1      1 -0.0007 -0.0004  ...          23.4190  191      0       0
# 1        1      2  0.0019 -0.0003  ...          23.4236  190      0       0
# 2        1      3 -0.0043  0.0003  ...          23.3442  189      0       0
# 3        1      4  0.0007  0.0000  ...          23.3739  188      0       0
# 4        1      5 -0.0019 -0.0002  ...          23.4044  187      0       0
# ...    ...    ...     ...     ...  ...              ...  ...    ...     ...
# 20626  100    196 -0.0004 -0.0003  ...          22.9735    4      1       1
# 20627  100    197 -0.0016 -0.0005  ...          23.1594    3      1       1
# 20628  100    198  0.0004  0.0000  ...          22.9333    2      1       1
# 20629  100    199 -0.0011  0.0003  ...          23.0640    1      1       1
# 20630  100    200 -0.0032 -0.0005  ...          23.0522    0      1       1
#
# [20631 rows x 29 columns]

# %%
# Analisando a distribuição da proporção de label
df_train['label2'].hist(bins=2, figsize=(7,7))
plt.xlabel("label")
plt.ylabel("frequencia")
print(str(round(df_train["label"].value_counts()[1]/df_train.shape[0]*100, 2)) + "% com defeito")
plt.show()
# Out:
# 15.03% com defeito

# %%
df_train = df_train.drop(['label2'], axis=1)

# %%
# Avaliando o desvio padrão dos sensores
df_train.iloc[:, 5:25].describe().transpose()
# Out:
#                    count         mean  ...        75%        max
# SensorMeasure1   20631.0   518.670000  ...   518.6700   518.6700
# SensorMeasure2   20631.0   642.680934  ...   643.0000   644.5300
# SensorMeasure3   20631.0  1590.523119  ...  1594.3800  1616.9100
# SensorMeasure4   20631.0  1408.933782  ...  1414.5550  1441.4900
# SensorMeasure5   20631.0    14.620000  ...    14.6200    14.6200
# SensorMeasure6   20631.0    21.609803  ...    21.6100    21.6100
# SensorMeasure7   20631.0   553.367711  ...   554.0100   556.0600
# SensorMeasure8   20631.0  2388.096652  ...  2388.1400  2388.5600
# SensorMeasure9   20631.0  9065.242941  ...  9069.4200  9244.5900
# SensorMeasure10  20631.0     1.300000  ...     1.3000     1.3000
# SensorMeasure11  20631.0    47.541168  ...    47.7000    48.5300
# SensorMeasure12  20631.0   521.413470  ...   521.9500   523.3800
# SensorMeasure13  20631.0  2388.096152  ...  2388.1400  2388.5600
# ...

# %% [markdown]
# **Sensores 1, 5, 10, 16 possuem desvio padrão muito baixo, logo serão descartados.**

# %%
# Analisando graficamente os dados
fig,ax=plt.subplots(7,3,figsize=(30,60))
c=0
for i in range(0,7):
    for j in range(0,3):
        plt.subplots_adjust(wspace=0.3, hspace=0.5)
        ax[i,j].scatter(df_train['RUL'], df_train['SensorMeasure'+str(c+1)],s=10,alpha=0.15, color='black')
        ax[i,j].set_title('SensorMeasure'+str(c+1), fontsize = 35)
        ax[i,j].set_xlabel("RUL", fontsize = 25)
        ax[i,j].set_ylabel("Sensor Reading", fontsize = 30)
        ax[i,j].tick_params(axis='both', labelsize=20)
        c+=1

# %% [markdown]
# **Serão descartados da análise os sensores 1, 5, 6, 10, 16 e 18 e 19**

# %%
# Normalizando os dados de treino
cols_normalize = df_train.columns.difference(['ID','Cycle','RUL','label'])
min_max_scaler = MinMaxScaler()
norm_df_train = pd.DataFrame(min_max_scaler.fit_transform(df_train[cols_normalize]), 
                             columns=cols_normalize, 
                             index=df_train.index)
join_df = df_train[df_train.columns.difference(cols_normalize)].join(norm_df_train)
df_train = join_df.reindex(columns = df_train.columns)
df_train.head()
# Out:
#    ID  Cycle    OpSet1    OpSet2  ...  SensorMeasure20  SensorMeasure21  RUL  label
# 0   1      1  0.459770  0.166667  ...         0.713178         0.724662  191      0
# 1   1      2  0.609195  0.250000  ...         0.666667         0.731014  190      0
# 2   1      3  0.252874  0.750000  ...         0.627907         0.621375  189      0
# 3   1      4  0.540230  0.500000  ...         0.573643         0.662386  188      0
# 4   1      5  0.390805  0.333333  ...         0.589147         0.704502  187      0
#
# [5 rows x 28 columns]

# %%
# Normalizando os dados de teste
norm_df_test = pd.DataFrame(min_max_scaler.transform(df_test[cols_normalize]), 
                            columns=cols_normalize, 
                            index=df_test.index)
test_join_df = df_test[df_test.columns.difference(cols_normalize)].join(norm_df_test)
df_test = test_join_df.reindex(columns = df_test.columns)
df_test = df_test.reset_index(drop=True)
df_test.head()
# Out:
#    ID  Cycle    OpSet1  ...  SensorMeasure19  SensorMeasure20  SensorMeasure21
# 0   1      1  0.632184  ...              0.0         0.558140         0.661834
# 1   1      2  0.344828  ...              0.0         0.682171         0.686827
# 2   1      3  0.517241  ...              0.0         0.728682         0.721348
# 3   1      4  0.741379  ...              0.0         0.666667         0.662110
# 4   1      5  0.580460  ...              0.0         0.658915         0.716377
#
# [5 rows x 26 columns]

# %%
# Criando a coluna RUL para o conjunto de dados de teste
# gerando a coluna max
rul = pd.DataFrame(df_test.groupby('ID')['Cycle'].max()).reset_index()
rul.columns = ['ID', 'max']
df_RUL.columns = ['more']
df_RUL['ID'] = df_RUL.index + 1
df_RUL['max'] = rul['max'] + df_RUL['more']
df_RUL.drop('more', axis=1, inplace=True)

# Gerando a coluna RUL
df_test = df_test.merge(df_RUL, on=['ID'], how='left')
df_test['RUL'] = df_test['max'] - df_test['Cycle']
df_test.drop('max', axis=1, inplace=True)
df_test.head()
# Out:
#    ID  Cycle    OpSet1  ...  SensorMeasure20  SensorMeasure21  RUL
# 0   1      1  0.632184  ...         0.558140         0.661834  142
# 1   1      2  0.344828  ...         0.682171         0.686827  141
# 2   1      3  0.517241  ...         0.728682         0.721348  140
# 3   1      4  0.741379  ...         0.666667         0.662110  139
# 4   1      5  0.580460  ...         0.658915         0.716377  138
#
# [5 rows x 27 columns]

# %%
# Retirando as colunas 1, 5, 6, 10, 16 e 18 e 19

df_train = df_train.drop(['SensorMeasure1','SensorMeasure5','SensorMeasure6','SensorMeasure10',
                          'SensorMeasure16','SensorMeasure18','SensorMeasure17','SensorMeasure19'], axis=1)
df_train.head()
# Out:
#    ID  Cycle    OpSet1    OpSet2  ...  SensorMeasure20  SensorMeasure21  RUL  label
# 0   1      1  0.459770  0.166667  ...         0.713178         0.724662  191      0
# 1   1      2  0.609195  0.250000  ...         0.666667         0.731014  190      0
# 2   1      3  0.252874  0.750000  ...         0.627907         0.621375  189      0
# 3   1      4  0.540230  0.500000  ...         0.573643         0.662386  188      0
# 4   1      5  0.390805  0.333333  ...         0.589147         0.704502  187      0
#
# [5 rows x 20 columns]

# %%
# Analisando um violin plot
fig, ax = pyplot.subplots(figsize =(26, 17)) 
sns.violinplot(ax = ax,  data = df_train.iloc[:, 5:18])
plt.ylabel('Leitura dos sensores', fontsize = 25)
plt.xticks(rotation = 90)
plt.tick_params(axis='both', labelsize=25)
plt.ylim(-0.5, 1.5)
#plt.yticks(labelsize = 25)
plt.grid()

# %%
# visualizando os dados de uma amostra das turbinas 
turbina_id1 = df_train[df_train['ID'] == 3]
turbina_id1_100cycleWindow = turbina_id1[turbina_id1['RUL'] <= turbina_id1['RUL'].min() + 100]
cols = ['SensorMeasure2', 'SensorMeasure3', 'SensorMeasure4', 'SensorMeasure7', 'SensorMeasure8', 'SensorMeasure9',
        'SensorMeasure11', 'SensorMeasure12', 'SensorMeasure13', 'SensorMeasure14', 'SensorMeasure15', 'SensorMeasure20', 'SensorMeasure21']
turbina_id1_100cycleWindow = turbina_id1_100cycleWindow[cols]

# plotting sensor data for engine ID 3 prior to a failure point
ax1 = turbina_id1_100cycleWindow.plot(subplots=True, sharex=True, figsize=(20,20))

# %%
# Adicionando label ao conjunto teste
D = 30
df_test['label'] = np.where(df_test['RUL'] <= D, 1, 0 )

# %%
# Retirando sensores inúteis do conjunto de testes
df_test = df_test.drop(['SensorMeasure1','SensorMeasure5','SensorMeasure6','SensorMeasure10',
                          'SensorMeasure16','SensorMeasure18','SensorMeasure17','SensorMeasure19'], axis=1)
df_test
# Out:
#         ID  Cycle    OpSet1  ...  SensorMeasure21  RUL  label
# 0        1      1  0.632184  ...         0.661834  142      0
# 1        1      2  0.344828  ...         0.686827  141      0
# 2        1      3  0.517241  ...         0.721348  140      0
# 3        1      4  0.741379  ...         0.662110  139      0
# 4        1      5  0.580460  ...         0.716377  138      0
# ...    ...    ...       ...  ...              ...  ...    ...
# 13091  100    194  0.781609  ...         0.418669   24      1
# 13092  100    195  0.436782  ...         0.528721   23      1
# 13093  100    196  0.465517  ...         0.429301   22      1
# 13094  100    197  0.281609  ...         0.518779   21      1
# 13095  100    198  0.574713  ...         0.402237   20      1
#
# [13096 rows x 20 columns]

# %%
# Salvando os conjuntos de treino e de teste
df_train.to_csv('df_train_30.csv')
df_test.to_csv('df_test.csv')
